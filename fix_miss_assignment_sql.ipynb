# %%
import numpy as np
import pandas as pd

# %%
bajaj = pd.read_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/Bajaj Auto.csv")
bajaj
bajaj.isnull().sum()
bajaj[pd.isnull(bajaj["Deliverable Quantity"])]
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 229  31-August-2017      2752.0     2820.95    2734.15      2808.45
#
#              WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 229  2789.230884         17407           1330            48552142.0
#
#      Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 229                   NaN                        NaN             86.8
#
#      Spread Close-Open
# 229              56.45

# %%
eicher = pd.read_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/Eicher Motors.csv")
hero = pd.read_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/Hero Motocorp.csv")
infosys = pd.read_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/Infosys.csv")
tcs = pd.read_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/TCS.csv")
tvs = pd.read_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/TVS Motors.csv")

print("eicher:")
print(eicher.isnull().sum())
print("")
print("hero")
print(hero.isnull().sum())
print("")
print("infosys")
print(infosys.isnull().sum())
print("")
print("tcs")
print(tcs.isnull().sum())
print("")
print("tvs")
print(tvs.isnull().sum())
# Out:
# eicher:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         1
# % Deli. Qty to Traded Qty    1
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64
#
# hero
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         1
# % Deli. Qty to Traded Qty    1
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64
#
# infosys
# Date                         0
# Open Price                   0
# ...

# %%
#padding blank with 0 for bajaj
bajaj.loc[bajaj["Deliverable Quantity"].isnull(), ["Deliverable Quantity"] ] = 0
bajaj.loc[bajaj["% Deli. Qty to Traded Qty"].isnull(), ["% Deli. Qty to Traded Qty"] ] = 0


#padding blank with 0 for eicher
eicher.loc[eicher["Deliverable Quantity"].isnull(), ["Deliverable Quantity"] ] = 0
eicher.loc[eicher["% Deli. Qty to Traded Qty"].isnull(), ["% Deli. Qty to Traded Qty"] ] = 0

#padding blank with 0 for hero
hero.loc[hero["Deliverable Quantity"].isnull(), ["Deliverable Quantity"] ] = 0
hero.loc[hero["% Deli. Qty to Traded Qty"].isnull(), ["% Deli. Qty to Traded Qty"] ] = 0

#padding blank with 0 for infosys
infosys.loc[infosys["Deliverable Quantity"].isnull(), ["Deliverable Quantity"] ] = 0
infosys.loc[infosys["% Deli. Qty to Traded Qty"].isnull(), ["% Deli. Qty to Traded Qty"] ] = 0

#padding blank with 0 for tcs
tcs.loc[tcs["Deliverable Quantity"].isnull(), ["Deliverable Quantity"] ] = 0
tcs.loc[tcs["% Deli. Qty to Traded Qty"].isnull(), ["% Deli. Qty to Traded Qty"] ] = 0

#padding blank with 0 for tvs
tvs.loc[tvs["Deliverable Quantity"].isnull(), ["Deliverable Quantity"] ] = 0
tvs.loc[tvs["% Deli. Qty to Traded Qty"].isnull(), ["% Deli. Qty to Traded Qty"] ] = 0

# %%
#check for NULL
print("eicher:")
print(eicher.isnull().sum())
print("")
print("hero")
print(hero.isnull().sum())
print("")
print("infosys")
print(infosys.isnull().sum())
print("")
print("tcs")
print(tcs.isnull().sum())
print("")
print("tvs")
print(tvs.isnull().sum())
# Out:
# eicher:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         0
# % Deli. Qty to Traded Qty    0
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64
#
# hero
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         0
# % Deli. Qty to Traded Qty    0
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64
#
# infosys
# Date                         0
# Open Price                   0
# ...

# %%
#output CSV files
bajaj.to_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/bajaj.csv", sep = ",", index = False)
eicher.to_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/eicher.csv", sep = ",", index = False)
hero.to_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/hero.csv", sep = ",", index = False)
infosys.to_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/infosys_full.csv", sep = ",", index = False)
tcs.to_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/tcs_full.csv", sep = ",", index = False)
tvs.to_csv("C:/Users/Rabi/Documents/Data_Science/upgrad/intro_to_data_management/Assignment/tvs.csv", sep = ",", index = False)
